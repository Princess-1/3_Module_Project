# %% [markdown]
# # Objective
# This is the first notebook in my **Chicago Traffic Crashes** data analysis project, and in the notebook I will be **importing** and **merging** the provided datasets.
#
# ### Order of Operations:
# * Obtain data
# * Explore the datasets we will be using to create our Models i.e, **Trafic_Crashes, Traffic_People,** and **Traffic_Vehicles**
#     - Filter out irrelevant columns
#     - Data type conversion
#     - Detect and handle missing data
#     - Deal with outliers in data if any
#     - Check for duplicates
#     - Create dummy variables for categorical data

# %% [markdown]
# ## Data Importing
# The first step in this process is to load obtained data into the notebook.

# %%
# First we need to import all necessary libraries

# For interacting with path/directory
import os 
from glob import glob

import pandas as pd  # For handle datasets and data storage
import sqlite3  # For joining datasets

# For data visualization
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# Import functions.py
from mydef import *

# %% [markdown]
# ### Traffic_Crashes - Load and Explore Dataset

# %%
# Start by importing and exploring the first dataset
crashes = pd.read_csv('CSV_Datasets/Traffic_Crashes.csv')
crashes.head().T
# Out:
#                                                                                0  \
# CRASH_RECORD_ID                4fd0a3e0897b3335b94cd8d5b2d2b350eb691add56c62d...
# RD_NO                                                                   JC343143
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE                                                07/10/2019 05:56:00 PM
# POSTED_SPEED_LIMIT                                                            35
# TRAFFIC_CONTROL_DEVICE                                               NO CONTROLS
# DEVICE_CONDITION                                                     NO CONTROLS
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                         TURNING
# TRAFFICWAY_TYPE                                                          ONE-WAY
# LANE_CNT                                                                     NaN
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                                             ON SCENE
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      07/10/2019 06:16:00 PM
# PRIM_CONTRIBUTORY_CAUSE                                         IMPROPER BACKING
# SEC_CONTRIBUTORY_CAUSE                                       UNABLE TO DETERMINE
# STREET_NO                                                                   2158
# STREET_DIRECTION                                                               N
# STREET_NAME                                                          MARMORA AVE
# BEAT_OF_OCCURRENCE                                                          2515
# PHOTOS_TAKEN_I                                                               NaN
# STATEMENTS_TAKEN_I                                                           NaN
# DOORING_I                                                                    NaN
# WORK_ZONE_I                                                                  NaN
# WORK_ZONE_TYPE                                                               NaN
# WORKERS_PRESENT_I                                                            NaN
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                                 0
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  0
# INJURIES_NO_INDICATION                                                         3
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                    17
# CRASH_DAY_OF_WEEK                                                              4
# CRASH_MONTH                                                                    7
# LATITUDE                                                                 41.9197
# LONGITUDE                                                               -87.7733
# LOCATION                                POINT (-87.773287883007 41.919663832993)
#
#                                                                                1  \
# CRASH_RECORD_ID                009e9e67203442370272e1a13d6ee51a4155dac65e583d...
# RD_NO                                                                   JA329216
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE                                                06/30/2017 04:00:00 PM
# POSTED_SPEED_LIMIT                                                            35
# TRAFFIC_CONTROL_DEVICE                                         STOP SIGN/FLASHER
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                         TURNING
# TRAFFICWAY_TYPE                                                      NOT DIVIDED
# LANE_CNT                                                                       4
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                                             ON SCENE
# CRASH_TYPE                                      INJURY AND / OR TOW DUE TO CRASH
# INTERSECTION_RELATED_I                                                         Y
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      06/30/2017 04:01:00 PM
# PRIM_CONTRIBUTORY_CAUSE                            FAILING TO YIELD RIGHT-OF-WAY
# SEC_CONTRIBUTORY_CAUSE                                            NOT APPLICABLE
# STREET_NO                                                                   8301
# STREET_DIRECTION                                                               S
# STREET_NAME                                                           CICERO AVE
# BEAT_OF_OCCURRENCE                                                           834
# PHOTOS_TAKEN_I                                                               NaN
# STATEMENTS_TAKEN_I                                                           NaN
# DOORING_I                                                                    NaN
# WORK_ZONE_I                                                                  NaN
# WORK_ZONE_TYPE                                                               NaN
# WORKERS_PRESENT_I                                                            NaN
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                                 0
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  0
# INJURIES_NO_INDICATION                                                         3
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                    16
# CRASH_DAY_OF_WEEK                                                              6
# CRASH_MONTH                                                                    6
# LATITUDE                                                                 41.7418
# LONGITUDE                                                                -87.741
# LOCATION                                POINT (-87.740953581987 41.741803598989)
#
#                                                                                2  \
# CRASH_RECORD_ID                ee9283eff3a55ac50ee58f3d9528ce1d689b1c4180b4c4...
# RD_NO                                                                   JD292400
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE                                                07/10/2020 10:25:00 AM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                        REAR END
# TRAFFICWAY_TYPE                                                         FOUR WAY
# LANE_CNT                                                                     NaN
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                                             ON SCENE
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      07/10/2020 10:25:00 AM
# PRIM_CONTRIBUTORY_CAUSE                            FAILING TO YIELD RIGHT-OF-WAY
# SEC_CONTRIBUTORY_CAUSE                             FAILING TO YIELD RIGHT-OF-WAY
# STREET_NO                                                                   1632
# STREET_DIRECTION                                                               E
# STREET_NAME                                                              67TH ST
# BEAT_OF_OCCURRENCE                                                           331
# PHOTOS_TAKEN_I                                                               NaN
# STATEMENTS_TAKEN_I                                                           NaN
# DOORING_I                                                                    NaN
# WORK_ZONE_I                                                                  NaN
# WORK_ZONE_TYPE                                                               NaN
# WORKERS_PRESENT_I                                                            NaN
# NUM_UNITS                                                                      3
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                                 0
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  0
# INJURIES_NO_INDICATION                                                         3
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                    10
# CRASH_DAY_OF_WEEK                                                              6
# CRASH_MONTH                                                                    7
# LATITUDE                                                                 41.7735
# LONGITUDE                                                                -87.585
# LOCATION                                POINT (-87.585022352022 41.773455972008)
#
#                                                                                3  \
# CRASH_RECORD_ID                f8960f698e870ebdc60b521b2a141a5395556bc3704191...
# RD_NO                                                                   JD293602
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE                                                07/11/2020 01:00:00 AM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                               NO CONTROLS
# DEVICE_CONDITION                                                     NO CONTROLS
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DARKNESS
# FIRST_CRASH_TYPE                                            PARKED MOTOR VEHICLE
# TRAFFICWAY_TYPE                                  DIVIDED - W/MEDIAN (NOT RAISED)
# LANE_CNT                                                                     NaN
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                  Y
# DAMAGE                                                              $500 OR LESS
# DATE_POLICE_NOTIFIED                                      07/11/2020 08:30:00 AM
# PRIM_CONTRIBUTORY_CAUSE                                      UNABLE TO DETERMINE
# SEC_CONTRIBUTORY_CAUSE                                       UNABLE TO DETERMINE
# STREET_NO                                                                    110
# STREET_DIRECTION                                                               E
# STREET_NAME                                                              51ST ST
# BEAT_OF_OCCURRENCE                                                           224
# PHOTOS_TAKEN_I                                                               NaN
# STATEMENTS_TAKEN_I                                                           NaN
# DOORING_I                                                                    NaN
# WORK_ZONE_I                                                                  NaN
# WORK_ZONE_TYPE                                                               NaN
# WORKERS_PRESENT_I                                                            NaN
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                                 0
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  0
# INJURIES_NO_INDICATION                                                         3
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                     1
# CRASH_DAY_OF_WEEK                                                              7
# CRASH_MONTH                                                                    7
# LATITUDE                                                                 41.8021
# LONGITUDE                                                               -87.6221
# LOCATION                                POINT (-87.622114914961 41.802118543011)
#
#                                                                                4
# CRASH_RECORD_ID                8eaa2678d1a127804ee9b8c35ddf7d63d913c14eda61d6...
# RD_NO                                                                   JD290451
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE                                                07/08/2020 02:00:00 PM
# POSTED_SPEED_LIMIT                                                            20
# TRAFFIC_CONTROL_DEVICE                                               NO CONTROLS
# DEVICE_CONDITION                                                     NO CONTROLS
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                            PARKED MOTOR VEHICLE
# TRAFFICWAY_TYPE                                                         DRIVEWAY
# LANE_CNT                                                                     NaN
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                                             ON SCENE
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      07/08/2020 02:15:00 PM
# PRIM_CONTRIBUTORY_CAUSE                                      UNABLE TO DETERMINE
# SEC_CONTRIBUTORY_CAUSE                                       UNABLE TO DETERMINE
# STREET_NO                                                                    412
# STREET_DIRECTION                                                               W
# STREET_NAME                                                             OHARE ST
# BEAT_OF_OCCURRENCE                                                          1654
# PHOTOS_TAKEN_I                                                               NaN
# STATEMENTS_TAKEN_I                                                           NaN
# DOORING_I                                                                    NaN
# WORK_ZONE_I                                                                  NaN
# WORK_ZONE_TYPE                                                               NaN
# WORKERS_PRESENT_I                                                            NaN
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                                 0
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  0
# INJURIES_NO_INDICATION                                                         1
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                    14
# CRASH_DAY_OF_WEEK                                                              4
# CRASH_MONTH                                                                    7
# LATITUDE                                                                     NaN
# LONGITUDE                                                                    NaN
# LOCATION                                                                     NaN

# %%
# View size of dataset
print(f'This dataset has {len(crashes)} rows and {len(crashes.columns)} columns\n')

# .info() to get more information on each column, i.e, dtypes, number of non-null values
crashes.info()
# Out:
# This dataset has 490128 rows and 49 columns
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490128 entries, 0 to 490127
# Data columns (total 49 columns):
# CRASH_RECORD_ID                  490128 non-null object
# RD_NO                            486363 non-null object
# CRASH_DATE_EST_I                 36817 non-null object
# CRASH_DATE                       490128 non-null object
# POSTED_SPEED_LIMIT               490128 non-null int64
# TRAFFIC_CONTROL_DEVICE           490128 non-null object
# DEVICE_CONDITION                 490128 non-null object
# WEATHER_CONDITION                490128 non-null object
# LIGHTING_CONDITION               490128 non-null object
# FIRST_CRASH_TYPE                 490128 non-null object
# TRAFFICWAY_TYPE                  490128 non-null object
# LANE_CNT                         198965 non-null float64
# ALIGNMENT                        490128 non-null object
# ROADWAY_SURFACE_COND             490128 non-null object
# ROAD_DEFECT                      490128 non-null object
# REPORT_TYPE                      478165 non-null object
# CRASH_TYPE                       490128 non-null object
# INTERSECTION_RELATED_I           110608 non-null object
# NOT_RIGHT_OF_WAY_I               23098 non-null object
# HIT_AND_RUN_I                    144603 non-null object
# DAMAGE                           490128 non-null object
# DATE_POLICE_NOTIFIED             490128 non-null object
# PRIM_CONTRIBUTORY_CAUSE          490128 non-null object
# SEC_CONTRIBUTORY_CAUSE           490128 non-null object
# STREET_NO                        490128 non-null int64
# STREET_DIRECTION                 490125 non-null object
# STREET_NAME                      490127 non-null object
# BEAT_OF_OCCURRENCE               490123 non-null float64
# PHOTOS_TAKEN_I                   6158 non-null object
# STATEMENTS_TAKEN_I               9892 non-null object
# DOORING_I                        1562 non-null object
# WORK_ZONE_I                      3149 non-null object
# WORK_ZONE_TYPE                   2483 non-null object
# WORKERS_PRESENT_I                756 non-null object
# NUM_UNITS                        490128 non-null int64
# MOST_SEVERE_INJURY               489132 non-null object
# INJURIES_TOTAL                   489143 non-null float64
# INJURIES_FATAL                   489143 non-null float64
# INJURIES_INCAPACITATING          489143 non-null float64
# INJURIES_NON_INCAPACITATING      489143 non-null float64
# INJURIES_REPORTED_NOT_EVIDENT    489143 non-null float64
# INJURIES_NO_INDICATION           489143 non-null float64
# INJURIES_UNKNOWN                 489143 non-null float64
# CRASH_HOUR                       490128 non-null int64
# CRASH_DAY_OF_WEEK                490128 non-null int64
# CRASH_MONTH                      490128 non-null int64
# LATITUDE                         487403 non-null float64
# LONGITUDE                        487403 non-null float64
# LOCATION                         487403 non-null object
# dtypes: float64(11), int64(6), object(32)
# memory usage: 183.2+ MB

# %% [markdown]
# A couple of things we know so far:
# * There are 482,332 rows and 49 columns.
# * Of all 49 columns, 27 columns have at least 1 missing data point.
# * Over half the dataset is an **object** datatype
#
# > With the information provided on each column by the [Chicago Data Portal](https://data.cityofchicago.org/Transportation/Traffic-Crashes-Crashes/85ca-t3if) I was able to preselect features I felt were irrelevant to this project. The next step would be to filter out those columns before moving forward.

# %%
# Specify columns to drop in new dataframe
columns_to_drop = crashes[['RD_NO', 'CRASH_DATE_EST_I', 'LANE_CNT', 'REPORT_TYPE', 'DATE_POLICE_NOTIFIED', 'STREET_NO',
                     'STREET_NO', 'STREET_NAME', 'PHOTOS_TAKEN_I', 'STATEMENTS_TAKEN_I', 'DOORING_I', 
                     'WORK_ZONE_TYPE', 'WORKERS_PRESENT_I', 'MOST_SEVERE_INJURY', 'INJURIES_TOTAL', 'INJURIES_FATAL',
                     'INJURIES_INCAPACITATING', 'INJURIES_NON_INCAPACITATING', 'INJURIES_REPORTED_NOT_EVIDENT',
                     'INJURIES_NO_INDICATION', 'INJURIES_UNKNOWN', 'CRASH_HOUR', 'CRASH_DAY_OF_WEEK', 'CRASH_MONTH', 
                     'LOCATION', 'BEAT_OF_OCCURRENCE', 'DAMAGE']]
columns_to_drop.head()
# Out:
#       RD_NO CRASH_DATE_EST_I  LANE_CNT                 REPORT_TYPE  \
# 0  JC343143              NaN       NaN                    ON SCENE
# 1  JA329216              NaN       4.0                    ON SCENE
# 2  JD292400              NaN       NaN                    ON SCENE
# 3  JD293602              NaN       NaN  NOT ON SCENE (DESK REPORT)
# 4  JD290451              NaN       NaN                    ON SCENE
#
#      DATE_POLICE_NOTIFIED  STREET_NO  STREET_NO  STREET_NAME PHOTOS_TAKEN_I  \
# 0  07/10/2019 06:16:00 PM       2158       2158  MARMORA AVE            NaN
# 1  06/30/2017 04:01:00 PM       8301       8301   CICERO AVE            NaN
# 2  07/10/2020 10:25:00 AM       1632       1632      67TH ST            NaN
# 3  07/11/2020 08:30:00 AM        110        110      51ST ST            NaN
# 4  07/08/2020 02:15:00 PM        412        412     OHARE ST            NaN
#
#   STATEMENTS_TAKEN_I  ... INJURIES_NON_INCAPACITATING  \
# 0                NaN  ...                         0.0
# 1                NaN  ...                         0.0
# 2                NaN  ...                         0.0
# 3                NaN  ...                         0.0
# 4                NaN  ...                         0.0
#
#   INJURIES_REPORTED_NOT_EVIDENT INJURIES_NO_INDICATION INJURIES_UNKNOWN  \
# 0                           0.0                    3.0              0.0
# 1                           0.0                    3.0              0.0
# 2                           0.0                    3.0              0.0
# 3                           0.0                    3.0              0.0
# 4                           0.0                    1.0              0.0
#
#    CRASH_HOUR  CRASH_DAY_OF_WEEK  CRASH_MONTH  \
# 0          17                  4            7
# 1          16                  6            6
# 2          10                  6            7
# 3           1                  7            7
# 4          14                  4            7
#
#                                    LOCATION  BEAT_OF_OCCURRENCE        DAMAGE
# 0  POINT (-87.773287883007 41.919663832993)              2515.0   OVER $1,500
# 1  POINT (-87.740953581987 41.741803598989)               834.0   OVER $1,500
# 2  POINT (-87.585022352022 41.773455972008)               331.0   OVER $1,500
# 3  POINT (-87.622114914961 41.802118543011)               224.0  $500 OR LESS
# 4                                       NaN              1654.0   OVER $1,500
#
# [5 rows x 27 columns]

# %%
# Drop irrelevant columns from dataset
crashes.drop(columns=columns_to_drop, axis=1, inplace=True)
crashes.head().T
# Out:
#                                                                          0  \
# CRASH_RECORD_ID          4fd0a3e0897b3335b94cd8d5b2d2b350eb691add56c62d...
# CRASH_DATE                                          07/10/2019 05:56:00 PM
# POSTED_SPEED_LIMIT                                                      35
# TRAFFIC_CONTROL_DEVICE                                         NO CONTROLS
# DEVICE_CONDITION                                               NO CONTROLS
# WEATHER_CONDITION                                                    CLEAR
# LIGHTING_CONDITION                                                DAYLIGHT
# FIRST_CRASH_TYPE                                                   TURNING
# TRAFFICWAY_TYPE                                                    ONE-WAY
# ALIGNMENT                                               STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                   DRY
# ROAD_DEFECT                                                     NO DEFECTS
# CRASH_TYPE                                          NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                 NaN
# NOT_RIGHT_OF_WAY_I                                                     NaN
# HIT_AND_RUN_I                                                          NaN
# PRIM_CONTRIBUTORY_CAUSE                                   IMPROPER BACKING
# SEC_CONTRIBUTORY_CAUSE                                 UNABLE TO DETERMINE
# STREET_DIRECTION                                                         N
# WORK_ZONE_I                                                            NaN
# NUM_UNITS                                                                2
# LATITUDE                                                           41.9197
# LONGITUDE                                                         -87.7733
#
#                                                                          1  \
# CRASH_RECORD_ID          009e9e67203442370272e1a13d6ee51a4155dac65e583d...
# CRASH_DATE                                          06/30/2017 04:00:00 PM
# POSTED_SPEED_LIMIT                                                      35
# TRAFFIC_CONTROL_DEVICE                                   STOP SIGN/FLASHER
# DEVICE_CONDITION                                      FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                    CLEAR
# LIGHTING_CONDITION                                                DAYLIGHT
# FIRST_CRASH_TYPE                                                   TURNING
# TRAFFICWAY_TYPE                                                NOT DIVIDED
# ALIGNMENT                                               STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                   DRY
# ROAD_DEFECT                                                     NO DEFECTS
# CRASH_TYPE                                INJURY AND / OR TOW DUE TO CRASH
# INTERSECTION_RELATED_I                                                   Y
# NOT_RIGHT_OF_WAY_I                                                     NaN
# HIT_AND_RUN_I                                                          NaN
# PRIM_CONTRIBUTORY_CAUSE                      FAILING TO YIELD RIGHT-OF-WAY
# SEC_CONTRIBUTORY_CAUSE                                      NOT APPLICABLE
# STREET_DIRECTION                                                         S
# WORK_ZONE_I                                                            NaN
# NUM_UNITS                                                                2
# LATITUDE                                                           41.7418
# LONGITUDE                                                          -87.741
#
#                                                                          2  \
# CRASH_RECORD_ID          ee9283eff3a55ac50ee58f3d9528ce1d689b1c4180b4c4...
# CRASH_DATE                                          07/10/2020 10:25:00 AM
# POSTED_SPEED_LIMIT                                                      30
# TRAFFIC_CONTROL_DEVICE                                      TRAFFIC SIGNAL
# DEVICE_CONDITION                                      FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                    CLEAR
# LIGHTING_CONDITION                                                DAYLIGHT
# FIRST_CRASH_TYPE                                                  REAR END
# TRAFFICWAY_TYPE                                                   FOUR WAY
# ALIGNMENT                                               STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                   DRY
# ROAD_DEFECT                                                     NO DEFECTS
# CRASH_TYPE                                          NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                 NaN
# NOT_RIGHT_OF_WAY_I                                                     NaN
# HIT_AND_RUN_I                                                          NaN
# PRIM_CONTRIBUTORY_CAUSE                      FAILING TO YIELD RIGHT-OF-WAY
# SEC_CONTRIBUTORY_CAUSE                       FAILING TO YIELD RIGHT-OF-WAY
# STREET_DIRECTION                                                         E
# WORK_ZONE_I                                                            NaN
# NUM_UNITS                                                                3
# LATITUDE                                                           41.7735
# LONGITUDE                                                          -87.585
#
#                                                                          3  \
# CRASH_RECORD_ID          f8960f698e870ebdc60b521b2a141a5395556bc3704191...
# CRASH_DATE                                          07/11/2020 01:00:00 AM
# POSTED_SPEED_LIMIT                                                      30
# TRAFFIC_CONTROL_DEVICE                                         NO CONTROLS
# DEVICE_CONDITION                                               NO CONTROLS
# WEATHER_CONDITION                                                    CLEAR
# LIGHTING_CONDITION                                                DARKNESS
# FIRST_CRASH_TYPE                                      PARKED MOTOR VEHICLE
# TRAFFICWAY_TYPE                            DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                               STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                   DRY
# ROAD_DEFECT                                                     NO DEFECTS
# CRASH_TYPE                                          NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                 NaN
# NOT_RIGHT_OF_WAY_I                                                     NaN
# HIT_AND_RUN_I                                                            Y
# PRIM_CONTRIBUTORY_CAUSE                                UNABLE TO DETERMINE
# SEC_CONTRIBUTORY_CAUSE                                 UNABLE TO DETERMINE
# STREET_DIRECTION                                                         E
# WORK_ZONE_I                                                            NaN
# NUM_UNITS                                                                2
# LATITUDE                                                           41.8021
# LONGITUDE                                                         -87.6221
#
#                                                                          4
# CRASH_RECORD_ID          8eaa2678d1a127804ee9b8c35ddf7d63d913c14eda61d6...
# CRASH_DATE                                          07/08/2020 02:00:00 PM
# POSTED_SPEED_LIMIT                                                      20
# TRAFFIC_CONTROL_DEVICE                                         NO CONTROLS
# DEVICE_CONDITION                                               NO CONTROLS
# WEATHER_CONDITION                                                    CLEAR
# LIGHTING_CONDITION                                                DAYLIGHT
# FIRST_CRASH_TYPE                                      PARKED MOTOR VEHICLE
# TRAFFICWAY_TYPE                                                   DRIVEWAY
# ALIGNMENT                                               STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                   DRY
# ROAD_DEFECT                                                     NO DEFECTS
# CRASH_TYPE                                          NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                 NaN
# NOT_RIGHT_OF_WAY_I                                                     NaN
# HIT_AND_RUN_I                                                          NaN
# PRIM_CONTRIBUTORY_CAUSE                                UNABLE TO DETERMINE
# SEC_CONTRIBUTORY_CAUSE                                 UNABLE TO DETERMINE
# STREET_DIRECTION                                                         W
# WORK_ZONE_I                                                            NaN
# NUM_UNITS                                                                2
# LATITUDE                                                               NaN
# LONGITUDE                                                              NaN

# %%
crashes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490128 entries, 0 to 490127
# Data columns (total 23 columns):
# CRASH_RECORD_ID            490128 non-null object
# CRASH_DATE                 490128 non-null object
# POSTED_SPEED_LIMIT         490128 non-null int64
# TRAFFIC_CONTROL_DEVICE     490128 non-null object
# DEVICE_CONDITION           490128 non-null object
# WEATHER_CONDITION          490128 non-null object
# LIGHTING_CONDITION         490128 non-null object
# FIRST_CRASH_TYPE           490128 non-null object
# TRAFFICWAY_TYPE            490128 non-null object
# ALIGNMENT                  490128 non-null object
# ROADWAY_SURFACE_COND       490128 non-null object
# ROAD_DEFECT                490128 non-null object
# CRASH_TYPE                 490128 non-null object
# INTERSECTION_RELATED_I     110608 non-null object
# NOT_RIGHT_OF_WAY_I         23098 non-null object
# HIT_AND_RUN_I              144603 non-null object
# PRIM_CONTRIBUTORY_CAUSE    490128 non-null object
# SEC_CONTRIBUTORY_CAUSE     490128 non-null object
# STREET_DIRECTION           490125 non-null object
# WORK_ZONE_I                3149 non-null object
# NUM_UNITS                  490128 non-null int64
# LATITUDE                   487403 non-null float64
# LONGITUDE                  487403 non-null float64
# dtypes: float64(2), int64(2), object(19)
# memory usage: 86.0+ MB

# %% [markdown]
# > Once all the unwanted columns have been removed we are left with only _23 columns_ in the **crashes** dataset

# %%
# Transform data back to csv file
crashes.to_csv('Column_Data/crashes.csv')

# %% [markdown]
# ### Traffic_People - Load and Explore Dataset

# %%
# Import People dataset into pandas dataframe
people = pd.read_csv('CSV_Datasets/Traffic_People.csv', dtype={12: str, 13: str, 20: str, 21: str, 22: str,
                                                               23: str, 24: str, 25: str, 26: str, 27: str, 29: str})
people.head().T
# Out:
#                                                                        0  \
# PERSON_ID                                                        O749947
# PERSON_TYPE                                                       DRIVER
# CRASH_RECORD_ID        81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...
# RD_NO                                                           JC451435
# VEHICLE_ID                                                        834816
# CRASH_DATE                                        09/28/2019 03:30:00 AM
# SEAT_NO                                                              NaN
# CITY                                                             CHICAGO
# STATE                                                                 IL
# ZIPCODE                                                            60651
# SEX                                                                    M
# AGE                                                                   25
# DRIVERS_LICENSE_STATE                                                 IL
# DRIVERS_LICENSE_CLASS                                                  D
# SAFETY_EQUIPMENT                                            NONE PRESENT
# AIRBAG_DEPLOYED                                       DEPLOYMENT UNKNOWN
# EJECTION                                                            NONE
# INJURY_CLASSIFICATION                            NO INDICATION OF INJURY
# HOSPITAL                                                             NaN
# EMS_AGENCY                                                           NaN
# EMS_RUN_NO                                                           NaN
# DRIVER_ACTION                                                    UNKNOWN
# DRIVER_VISION                                                    UNKNOWN
# PHYSICAL_CONDITION                                               UNKNOWN
# PEDPEDAL_ACTION                                                      NaN
# PEDPEDAL_VISIBILITY                                                  NaN
# PEDPEDAL_LOCATION                                                    NaN
# BAC_RESULT                                              TEST NOT OFFERED
# BAC_RESULT VALUE                                                     NaN
# CELL_PHONE_USE                                                       NaN
#
#                                                                        1  \
# PERSON_ID                                                        O871921
# PERSON_TYPE                                                       DRIVER
# CRASH_RECORD_ID        af84fb5c8d996fcd3aefd36593c3a02e6e7509eeb27568...
# RD_NO                                                           JD208731
# VEHICLE_ID                                                        827212
# CRASH_DATE                                        04/13/2020 10:50:00 PM
# SEAT_NO                                                              NaN
# CITY                                                             CHICAGO
# STATE                                                                 IL
# ZIPCODE                                                            60620
# SEX                                                                    M
# AGE                                                                   37
# DRIVERS_LICENSE_STATE                                                 IL
# DRIVERS_LICENSE_CLASS                                                NaN
# SAFETY_EQUIPMENT                                        SAFETY BELT USED
# AIRBAG_DEPLOYED                                           DID NOT DEPLOY
# EJECTION                                                            NONE
# INJURY_CLASSIFICATION                            NO INDICATION OF INJURY
# HOSPITAL                                                             NaN
# EMS_AGENCY                                                           NaN
# EMS_RUN_NO                                                           NaN
# DRIVER_ACTION                                                       NONE
# DRIVER_VISION                                               NOT OBSCURED
# PHYSICAL_CONDITION                                                NORMAL
# PEDPEDAL_ACTION                                                      NaN
# PEDPEDAL_VISIBILITY                                                  NaN
# PEDPEDAL_LOCATION                                                    NaN
# BAC_RESULT                                              TEST NOT OFFERED
# BAC_RESULT VALUE                                                     NaN
# CELL_PHONE_USE                                                       NaN
#
#                                                                        2  \
# PERSON_ID                                                         O10018
# PERSON_TYPE                                                       DRIVER
# CRASH_RECORD_ID        71162af7bf22799b776547132ebf134b5b438dcf3dac6b...
# RD_NO                                                           HY484534
# VEHICLE_ID                                                          9579
# CRASH_DATE                                        11/01/2015 05:00:00 AM
# SEAT_NO                                                              NaN
# CITY                                                                 NaN
# STATE                                                                NaN
# ZIPCODE                                                              NaN
# SEX                                                                    X
# AGE                                                                  NaN
# DRIVERS_LICENSE_STATE                                                NaN
# DRIVERS_LICENSE_CLASS                                                NaN
# SAFETY_EQUIPMENT                                           USAGE UNKNOWN
# AIRBAG_DEPLOYED                                       DEPLOYMENT UNKNOWN
# EJECTION                                                            NONE
# INJURY_CLASSIFICATION                            NO INDICATION OF INJURY
# HOSPITAL                                                             NaN
# EMS_AGENCY                                                           NaN
# EMS_RUN_NO                                                           NaN
# DRIVER_ACTION                                           IMPROPER BACKING
# DRIVER_VISION                                                    UNKNOWN
# PHYSICAL_CONDITION                                               UNKNOWN
# PEDPEDAL_ACTION                                                      NaN
# PEDPEDAL_VISIBILITY                                                  NaN
# PEDPEDAL_LOCATION                                                    NaN
# BAC_RESULT                                              TEST NOT OFFERED
# BAC_RESULT VALUE                                                     NaN
# CELL_PHONE_USE                                                       NaN
#
#                                                                        3  \
# PERSON_ID                                                         O10038
# PERSON_TYPE                                                       DRIVER
# CRASH_RECORD_ID        c21c476e2ccc41af550b5d858d22aaac4ffc88745a1700...
# RD_NO                                                           HY484750
# VEHICLE_ID                                                          9598
# CRASH_DATE                                        11/01/2015 08:00:00 AM
# SEAT_NO                                                              NaN
# CITY                                                                 NaN
# STATE                                                                NaN
# ZIPCODE                                                              NaN
# SEX                                                                    X
# AGE                                                                  NaN
# DRIVERS_LICENSE_STATE                                                NaN
# DRIVERS_LICENSE_CLASS                                                NaN
# SAFETY_EQUIPMENT                                           USAGE UNKNOWN
# AIRBAG_DEPLOYED                                       DEPLOYMENT UNKNOWN
# EJECTION                                                         UNKNOWN
# INJURY_CLASSIFICATION                            NO INDICATION OF INJURY
# HOSPITAL                                                             NaN
# EMS_AGENCY                                                           NaN
# EMS_RUN_NO                                                           NaN
# DRIVER_ACTION                                                    UNKNOWN
# DRIVER_VISION                                                    UNKNOWN
# PHYSICAL_CONDITION                                               UNKNOWN
# PEDPEDAL_ACTION                                                      NaN
# PEDPEDAL_VISIBILITY                                                  NaN
# PEDPEDAL_LOCATION                                                    NaN
# BAC_RESULT                                              TEST NOT OFFERED
# BAC_RESULT VALUE                                                     NaN
# CELL_PHONE_USE                                                       NaN
#
#                                                                        4
# PERSON_ID                                                         O10039
# PERSON_TYPE                                                       DRIVER
# CRASH_RECORD_ID        eb390a4c8e114c69488f5fb8a097fe629f5a92fd528cf4...
# RD_NO                                                           HY484778
# VEHICLE_ID                                                          9600
# CRASH_DATE                                        11/01/2015 10:15:00 AM
# SEAT_NO                                                              NaN
# CITY                                                                 NaN
# STATE                                                                NaN
# ZIPCODE                                                              NaN
# SEX                                                                    X
# AGE                                                                  NaN
# DRIVERS_LICENSE_STATE                                                NaN
# DRIVERS_LICENSE_CLASS                                                NaN
# SAFETY_EQUIPMENT                                           USAGE UNKNOWN
# AIRBAG_DEPLOYED                                       DEPLOYMENT UNKNOWN
# EJECTION                                                         UNKNOWN
# INJURY_CLASSIFICATION                            NO INDICATION OF INJURY
# HOSPITAL                                                             NaN
# EMS_AGENCY                                                           NaN
# EMS_RUN_NO                                                           NaN
# DRIVER_ACTION                                                    UNKNOWN
# DRIVER_VISION                                                    UNKNOWN
# PHYSICAL_CONDITION                                               UNKNOWN
# PEDPEDAL_ACTION                                                      NaN
# PEDPEDAL_VISIBILITY                                                  NaN
# PEDPEDAL_LOCATION                                                    NaN
# BAC_RESULT                                              TEST NOT OFFERED
# BAC_RESULT VALUE                                                     NaN
# CELL_PHONE_USE                                                       NaN

# %%
# View size of dataset
print(f'This dataset has {len(people)} rows and {len(people.columns)} columns\n')

# .info() to get more information on each column, i.e, dtypes, number of non-null values
people.info()
# Out:
# This dataset has 1082930 rows and 30 columns
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1082930 entries, 0 to 1082929
# Data columns (total 30 columns):
# PERSON_ID                1082930 non-null object
# PERSON_TYPE              1082930 non-null object
# CRASH_RECORD_ID          1082930 non-null object
# RD_NO                    1074735 non-null object
# VEHICLE_ID               1061532 non-null float64
# CRASH_DATE               1082930 non-null object
# SEAT_NO                  221187 non-null float64
# CITY                     800166 non-null object
# STATE                    809138 non-null object
# ZIPCODE                  730702 non-null object
# SEX                      1066874 non-null object
# AGE                      774106 non-null float64
# DRIVERS_LICENSE_STATE    641945 non-null object
# DRIVERS_LICENSE_CLASS    556876 non-null object
# SAFETY_EQUIPMENT         1079716 non-null object
# AIRBAG_DEPLOYED          1062470 non-null object
# EJECTION                 1069572 non-null object
# INJURY_CLASSIFICATION    1082362 non-null object
# HOSPITAL                 196780 non-null object
# EMS_AGENCY               124842 non-null object
# EMS_RUN_NO               20293 non-null object
# DRIVER_ACTION            859659 non-null object
# DRIVER_VISION            859374 non-null object
# PHYSICAL_CONDITION       860283 non-null object
# PEDPEDAL_ACTION          20091 non-null object
# PEDPEDAL_VISIBILITY      20048 non-null object
# PEDPEDAL_LOCATION        20092 non-null object
# BAC_RESULT               860776 non-null object
# BAC_RESULT VALUE         1394 non-null float64
# CELL_PHONE_USE           1157 non-null object
# dtypes: float64(4), object(26)
# memory usage: 247.9+ MB

# %% [markdown]
# A couple of things to note:
# * This dataset has **1,065,552 rows**, over double the size of the **crashes** dataset, and **30 columns**.
# * Only 4 columns appear to not have any missing data point.
# * Majority of the data is an **object** datatype
#
# > Just like the **crashes** dataset we will only be using columns I feel are relevant to the model.

# %%
# Reassign choosen columns to people Dataframe
people = people[['CRASH_RECORD_ID', 'SEX', 'AGE', 'SAFETY_EQUIPMENT', 'DRIVER_ACTION', 'DRIVER_VISION',
                 'PHYSICAL_CONDITION', 'BAC_RESULT']]
people.head()
# Out:
#                                      CRASH_RECORD_ID SEX   AGE  \
# 0  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...   M  25.0
# 1  af84fb5c8d996fcd3aefd36593c3a02e6e7509eeb27568...   M  37.0
# 2  71162af7bf22799b776547132ebf134b5b438dcf3dac6b...   X   NaN
# 3  c21c476e2ccc41af550b5d858d22aaac4ffc88745a1700...   X   NaN
# 4  eb390a4c8e114c69488f5fb8a097fe629f5a92fd528cf4...   X   NaN
#
#    SAFETY_EQUIPMENT     DRIVER_ACTION DRIVER_VISION PHYSICAL_CONDITION  \
# 0      NONE PRESENT           UNKNOWN       UNKNOWN            UNKNOWN
# 1  SAFETY BELT USED              NONE  NOT OBSCURED             NORMAL
# 2     USAGE UNKNOWN  IMPROPER BACKING       UNKNOWN            UNKNOWN
# 3     USAGE UNKNOWN           UNKNOWN       UNKNOWN            UNKNOWN
# 4     USAGE UNKNOWN           UNKNOWN       UNKNOWN            UNKNOWN
#
#          BAC_RESULT
# 0  TEST NOT OFFERED
# 1  TEST NOT OFFERED
# 2  TEST NOT OFFERED
# 3  TEST NOT OFFERED
# 4  TEST NOT OFFERED

# %% [markdown]
# > Of all **30 columns** only **8 columns** have been selected as _predictors_ for the model.

# %%
# Transform data back to csv file
people.to_csv('Column_Data/people.csv')

# %% [markdown]
# ### Traffic_Vehicles - Load and Explore Dataset
# Lastly we will be taking a look at the **Traffic_Vehicles** dataset

# %%
# Import Vehicles dataset into pandas dataframe
vehicles = pd.read_csv('CSV_Datasets/Traffic_Vehicles.csv', dtype={19: str, 21: str, 40: str, 41: str, 42: str,
                                                                   44: str, 48: str, 49: str, 50: str, 53: str, 
                                                                   55: str, 58: str, 59: str, 61: str, 71: str})
vehicles.head(10).T
# Out:
#                                                                          0  \
# CRASH_UNIT_ID                                                       829999
# CRASH_RECORD_ID          24ddf9fd8542199d832e1c223cc474e5601b356f1d77a6...
# RD_NO                                                             JD124535
# CRASH_DATE                                          01/22/2020 06:25:00 AM
# UNIT_NO                                                                  1
# ...                                                                    ...
# CARGO_BODY_TYPE                                                        NaN
# LOAD_TYPE                                                              NaN
# HAZMAT_OUT_OF_SERVICE_I                                                NaN
# MCS_OUT_OF_SERVICE_I                                                   NaN
# HAZMAT_CLASS                                                           NaN
#
#                                                                          1  \
# CRASH_UNIT_ID                                                       749947
# CRASH_RECORD_ID          81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...
# RD_NO                                                             JC451435
# CRASH_DATE                                          09/28/2019 03:30:00 AM
# UNIT_NO                                                                  1
# ...                                                                    ...
# CARGO_BODY_TYPE                                                        NaN
# LOAD_TYPE                                                              NaN
# HAZMAT_OUT_OF_SERVICE_I                                                NaN
# MCS_OUT_OF_SERVICE_I                                                   NaN
# HAZMAT_CLASS                                                           NaN
#
#                                                                          2  \
# CRASH_UNIT_ID                                                       749949
# CRASH_RECORD_ID          81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...
# RD_NO                                                             JC451435
# CRASH_DATE                                          09/28/2019 03:30:00 AM
# UNIT_NO                                                                  2
# ...                                                                    ...
# CARGO_BODY_TYPE                                                        NaN
# LOAD_TYPE                                                              NaN
# HAZMAT_OUT_OF_SERVICE_I                                                NaN
# MCS_OUT_OF_SERVICE_I                                                   NaN
# HAZMAT_CLASS                                                           NaN
#
#                                                                          3  \
# CRASH_UNIT_ID                                                       749950
# CRASH_RECORD_ID          81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...
# RD_NO                                                             JC451435
# CRASH_DATE                                          09/28/2019 03:30:00 AM
# UNIT_NO                                                                  3
# ...                                                                    ...
# CARGO_BODY_TYPE                                                        NaN
# LOAD_TYPE                                                              NaN
# HAZMAT_OUT_OF_SERVICE_I                                                NaN
# MCS_OUT_OF_SERVICE_I                                                   NaN
# HAZMAT_CLASS                                                           NaN
#
#                                                                          4  \
# CRASH_UNIT_ID                                                       871921
# CRASH_RECORD_ID          af84fb5c8d996fcd3aefd36593c3a02e6e7509eeb27568...
# RD_NO                                                             JD208731
# CRASH_DATE                                          04/13/2020 10:50:00 PM
# UNIT_NO                                                                  2
# ...                                                                    ...
# CARGO_BODY_TYPE                                                        NaN
# LOAD_TYPE                                                              NaN
# HAZMAT_OUT_OF_SERVICE_I                                                NaN
# MCS_OUT_OF_SERVICE_I                                                   NaN
# HAZMAT_CLASS                                                           NaN
#
#                                                                          5  \
# CRASH_UNIT_ID                                                       473653
# CRASH_RECORD_ID          80f5b6eff349a72094c9c7a11745549caa8bd39b57cedd...
# RD_NO                                                             JB428391
# CRASH_DATE                                          09/09/2018 08:50:00 AM
# UNIT_NO                                                                  2
# ...                                                                    ...
# CARGO_BODY_TYPE                                                        NaN
# LOAD_TYPE                                                              NaN
# HAZMAT_OUT_OF_SERVICE_I                                                NaN
# MCS_OUT_OF_SERVICE_I                                                   NaN
# HAZMAT_CLASS                                                           NaN
#
#                                                                          6  \
# CRASH_UNIT_ID                                                       834812
# CRASH_RECORD_ID          ecf9e646f89a73ed3df0f373e4fbd18e91f5a595004019...
# RD_NO                                                             JD138756
# CRASH_DATE                                          02/03/2020 03:45:00 PM
# UNIT_NO                                                                  1
# ...                                                                    ...
# CARGO_BODY_TYPE                                                        NaN
# LOAD_TYPE                                                              NaN
# HAZMAT_OUT_OF_SERVICE_I                                                NaN
# MCS_OUT_OF_SERVICE_I                                                   NaN
# HAZMAT_CLASS                                                           NaN
#
#                                                                          7  \
# CRASH_UNIT_ID                                                       834813
# CRASH_RECORD_ID          ecf9e646f89a73ed3df0f373e4fbd18e91f5a595004019...
# RD_NO                                                             JD138756
# CRASH_DATE                                          02/03/2020 03:45:00 PM
# UNIT_NO                                                                  2
# ...                                                                    ...
# CARGO_BODY_TYPE                                                        NaN
# LOAD_TYPE                                                              NaN
# HAZMAT_OUT_OF_SERVICE_I                                                NaN
# MCS_OUT_OF_SERVICE_I                                                   NaN
# HAZMAT_CLASS                                                           NaN
#
#                                                                          8  \
# CRASH_UNIT_ID                                                       837380
# CRASH_RECORD_ID          c7c57a49274b3aa953d0b76346f68e116ed8c3d72a683a...
# RD_NO                                                             JD143282
# CRASH_DATE                                          02/06/2020 12:00:00 AM
# UNIT_NO                                                                  1
# ...                                                                    ...
# CARGO_BODY_TYPE                                                        NaN
# LOAD_TYPE                                                              NaN
# HAZMAT_OUT_OF_SERVICE_I                                                NaN
# MCS_OUT_OF_SERVICE_I                                                   NaN
# HAZMAT_CLASS                                                           NaN
#
#                                                                          9
# CRASH_UNIT_ID                                                       837381
# CRASH_RECORD_ID          c7c57a49274b3aa953d0b76346f68e116ed8c3d72a683a...
# RD_NO                                                             JD143282
# CRASH_DATE                                          02/06/2020 12:00:00 AM
# UNIT_NO                                                                  2
# ...                                                                    ...
# CARGO_BODY_TYPE                                                        NaN
# LOAD_TYPE                                                              NaN
# HAZMAT_OUT_OF_SERVICE_I                                                NaN
# MCS_OUT_OF_SERVICE_I                                                   NaN
# HAZMAT_CLASS                                                           NaN
#
# [72 rows x 10 columns]

# %%
# View size of dataset
print(f'This dataset has {len(vehicles)} rows and {len(vehicles.columns)} columns\n')

# .info() to get more information on each column, i.e, dtypes, number of non-null values
vehicles.info()
# Out:
# This dataset has 1000837 rows and 72 columns
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000837 entries, 0 to 1000836
# Data columns (total 72 columns):
# CRASH_UNIT_ID               1000837 non-null int64
# CRASH_RECORD_ID             1000837 non-null object
# RD_NO                       993096 non-null object
# CRASH_DATE                  1000837 non-null object
# UNIT_NO                     1000837 non-null int64
# UNIT_TYPE                   999339 non-null object
# NUM_PASSENGERS              149754 non-null float64
# VEHICLE_ID                  977810 non-null float64
# CMRC_VEH_I                  18670 non-null object
# MAKE                        977805 non-null object
# MODEL                       977663 non-null object
# LIC_PLATE_STATE             894385 non-null object
# VEHICLE_YEAR                819278 non-null float64
# VEHICLE_DEFECT              977810 non-null object
# VEHICLE_TYPE                977810 non-null object
# VEHICLE_USE                 977810 non-null object
# TRAVEL_DIRECTION            977810 non-null object
# MANEUVER                    977810 non-null object
# TOWED_I                     113198 non-null object
# FIRE_I                      730 non-null object
# OCCUPANT_CNT                977810 non-null float64
# EXCEED_SPEED_LIMIT_I        2389 non-null object
# TOWED_BY                    82687 non-null object
# TOWED_TO                    51729 non-null object
# AREA_00_I                   38924 non-null object
# AREA_01_I                   259419 non-null object
# AREA_02_I                   170667 non-null object
# AREA_03_I                   94714 non-null object
# AREA_04_I                   99717 non-null object
# AREA_05_I                   151777 non-null object
# AREA_06_I                   150405 non-null object
# AREA_07_I                   129294 non-null object
# AREA_08_I                   167862 non-null object
# AREA_09_I                   41488 non-null object
# AREA_10_I                   60019 non-null object
# AREA_11_I                   119730 non-null object
# AREA_12_I                   117883 non-null object
# AREA_99_I                   105412 non-null object
# FIRST_CONTACT_POINT         971206 non-null object
# CMV_ID                      10651 non-null float64
# USDOT_NO                    6215 non-null object
# CCMC_NO                     1395 non-null object
# ILCC_NO                     1010 non-null object
# COMMERCIAL_SRC              7607 non-null object
# GVWR                        6193 non-null object
# CARRIER_NAME                10212 non-null object
# CARRIER_STATE               9657 non-null object
# CARRIER_CITY                9484 non-null object
# HAZMAT_PLACARDS_I           217 non-null object
# HAZMAT_NAME                 39 non-null object
# UN_NO                       392 non-null object
# HAZMAT_PRESENT_I            7866 non-null object
# HAZMAT_REPORT_I             7622 non-null object
# HAZMAT_REPORT_NO            1 non-null object
# MCS_REPORT_I                7673 non-null object
# MCS_REPORT_NO               5 non-null object
# HAZMAT_VIO_CAUSE_CRASH_I    7744 non-null object
# MCS_VIO_CAUSE_CRASH_I       7615 non-null object
# IDOT_PERMIT_NO              633 non-null object
# WIDE_LOAD_I                 91 non-null object
# TRAILER1_WIDTH              2184 non-null object
# TRAILER2_WIDTH              244 non-null object
# TRAILER1_LENGTH             1787 non-null float64
# TRAILER2_LENGTH             47 non-null float64
# TOTAL_VEHICLE_LENGTH        2155 non-null float64
# AXLE_CNT                    3100 non-null float64
# VEHICLE_CONFIG              8871 non-null object
# CARGO_BODY_TYPE             8492 non-null object
# LOAD_TYPE                   8130 non-null object
# HAZMAT_OUT_OF_SERVICE_I     7407 non-null object
# MCS_OUT_OF_SERVICE_I        7603 non-null object
# HAZMAT_CLASS                729 non-null object
# dtypes: float64(9), int64(2), object(61)
# memory usage: 549.8+ MB

# %% [markdown]
# A couple of things to note:
# * This dataset has **984,626 rows**, almost as much as the **peoples** dataset, and **72 columns** which is a lot more than the first two datasets.
# * This dataset has a lot more missing data per column overall
# * Majority of the data is an **object** datatype
# > Just like the first two datasets we will be choosing only columns relevant to the analysis.

# %%
# Reassign choosen columns to vehicles Dataframe
vehicles = vehicles[['CRASH_RECORD_ID', 'VEHICLE_DEFECT', 'TRAVEL_DIRECTION', 'EXCEED_SPEED_LIMIT_I', 'MANEUVER',
                 'FIRST_CONTACT_POINT']]
vehicles.head()
# Out:
#                                      CRASH_RECORD_ID VEHICLE_DEFECT  \
# 0  24ddf9fd8542199d832e1c223cc474e5601b356f1d77a6...           NONE
# 1  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...        UNKNOWN
# 2  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...           NONE
# 3  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...        UNKNOWN
# 4  af84fb5c8d996fcd3aefd36593c3a02e6e7509eeb27568...           NONE
#
#   TRAVEL_DIRECTION EXCEED_SPEED_LIMIT_I        MANEUVER FIRST_CONTACT_POINT
# 0                N                  NaN  STRAIGHT AHEAD               FRONT
# 1                N                  NaN  STRAIGHT AHEAD               FRONT
# 2                N                  NaN          PARKED                ROOF
# 3                N                  NaN          PARKED                ROOF
# 4                W                  NaN  STRAIGHT AHEAD         FRONT-RIGHT

# %% [markdown]
# > Only 6 of the columns in this dataset will be used for modeling.

# %%
# Transform data back to csv file
vehicles.to_csv('Column_Data/vehicles.csv')

# %% [markdown]
# ## Join Dataframes
# Now that the columns we wish to use for our analysis have been selected, the next step would be to join the new dataframes into one.

# %%
# Let's start by importing the new dataframes with our selected columns
# Add index_col to avoid extra index column when data loads
crashe_df = pd.read_csv('Column_Data/crashes.csv', index_col=0)
crashe_df.head()
# Out:
#                                      CRASH_RECORD_ID              CRASH_DATE  \
# 0  4fd0a3e0897b3335b94cd8d5b2d2b350eb691add56c62d...  07/10/2019 05:56:00 PM
# 1  009e9e67203442370272e1a13d6ee51a4155dac65e583d...  06/30/2017 04:00:00 PM
# 2  ee9283eff3a55ac50ee58f3d9528ce1d689b1c4180b4c4...  07/10/2020 10:25:00 AM
# 3  f8960f698e870ebdc60b521b2a141a5395556bc3704191...  07/11/2020 01:00:00 AM
# 4  8eaa2678d1a127804ee9b8c35ddf7d63d913c14eda61d6...  07/08/2020 02:00:00 PM
#
#    POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION  \
# 0                  35            NO CONTROLS           NO CONTROLS
# 1                  35      STOP SIGN/FLASHER  FUNCTIONING PROPERLY
# 2                  30         TRAFFIC SIGNAL  FUNCTIONING PROPERLY
# 3                  30            NO CONTROLS           NO CONTROLS
# 4                  20            NO CONTROLS           NO CONTROLS
#
#   WEATHER_CONDITION LIGHTING_CONDITION      FIRST_CRASH_TYPE  \
# 0             CLEAR           DAYLIGHT               TURNING
# 1             CLEAR           DAYLIGHT               TURNING
# 2             CLEAR           DAYLIGHT              REAR END
# 3             CLEAR           DARKNESS  PARKED MOTOR VEHICLE
# 4             CLEAR           DAYLIGHT  PARKED MOTOR VEHICLE
#
#                    TRAFFICWAY_TYPE           ALIGNMENT  ...  \
# 0                          ONE-WAY  STRAIGHT AND LEVEL  ...
# 1                      NOT DIVIDED  STRAIGHT AND LEVEL  ...
# 2                         FOUR WAY  STRAIGHT AND LEVEL  ...
# 3  DIVIDED - W/MEDIAN (NOT RAISED)  STRAIGHT AND LEVEL  ...
# 4                         DRIVEWAY  STRAIGHT AND LEVEL  ...
#
#   INTERSECTION_RELATED_I NOT_RIGHT_OF_WAY_I HIT_AND_RUN_I  \
# 0                    NaN                NaN           NaN
# 1                      Y                NaN           NaN
# 2                    NaN                NaN           NaN
# 3                    NaN                NaN             Y
# 4                    NaN                NaN           NaN
#
#          PRIM_CONTRIBUTORY_CAUSE         SEC_CONTRIBUTORY_CAUSE  \
# 0               IMPROPER BACKING            UNABLE TO DETERMINE
# 1  FAILING TO YIELD RIGHT-OF-WAY                 NOT APPLICABLE
# 2  FAILING TO YIELD RIGHT-OF-WAY  FAILING TO YIELD RIGHT-OF-WAY
# 3            UNABLE TO DETERMINE            UNABLE TO DETERMINE
# 4            UNABLE TO DETERMINE            UNABLE TO DETERMINE
#
#   STREET_DIRECTION WORK_ZONE_I NUM_UNITS   LATITUDE  LONGITUDE
# 0                N         NaN         2  41.919664 -87.773288
# 1                S         NaN         2  41.741804 -87.740954
# 2                E         NaN         3  41.773456 -87.585022
# 3                E         NaN         2  41.802119 -87.622115
# 4                W         NaN         2        NaN        NaN
#
# [5 rows x 23 columns]

# %%
vehicle_df = pd.read_csv('Column_Data/vehicles.csv', index_col=0)
vehicle_df.head()
# Out:
# /usr/local/anaconda3/envs/learn-env/lib/python3.6/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                                      CRASH_RECORD_ID VEHICLE_DEFECT  \
# 0  24ddf9fd8542199d832e1c223cc474e5601b356f1d77a6...           NONE
# 1  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...        UNKNOWN
# 2  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...           NONE
# 3  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...        UNKNOWN
# 4  af84fb5c8d996fcd3aefd36593c3a02e6e7509eeb27568...           NONE
#
#   TRAVEL_DIRECTION EXCEED_SPEED_LIMIT_I        MANEUVER FIRST_CONTACT_POINT
# 0                N                  NaN  STRAIGHT AHEAD               FRONT
# 1                N                  NaN  STRAIGHT AHEAD               FRONT
# 2                N                  NaN          PARKED                ROOF
# 3                N                  NaN          PARKED                ROOF
# 4                W                  NaN  STRAIGHT AHEAD         FRONT-RIGHT

# %%
people_df = pd.read_csv('Column_Data/people.csv', index_col=0)
people_df.head()
# Out:
# /usr/local/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                      CRASH_RECORD_ID SEX   AGE  \
# 0  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...   M  25.0
# 1  af84fb5c8d996fcd3aefd36593c3a02e6e7509eeb27568...   M  37.0
# 2  71162af7bf22799b776547132ebf134b5b438dcf3dac6b...   X   NaN
# 3  c21c476e2ccc41af550b5d858d22aaac4ffc88745a1700...   X   NaN
# 4  eb390a4c8e114c69488f5fb8a097fe629f5a92fd528cf4...   X   NaN
#
#    SAFETY_EQUIPMENT     DRIVER_ACTION DRIVER_VISION PHYSICAL_CONDITION  \
# 0      NONE PRESENT           UNKNOWN       UNKNOWN            UNKNOWN
# 1  SAFETY BELT USED              NONE  NOT OBSCURED             NORMAL
# 2     USAGE UNKNOWN  IMPROPER BACKING       UNKNOWN            UNKNOWN
# 3     USAGE UNKNOWN           UNKNOWN       UNKNOWN            UNKNOWN
# 4     USAGE UNKNOWN           UNKNOWN       UNKNOWN            UNKNOWN
#
#          BAC_RESULT
# 0  TEST NOT OFFERED
# 1  TEST NOT OFFERED
# 2  TEST NOT OFFERED
# 3  TEST NOT OFFERED
# 4  TEST NOT OFFERED

# %% [markdown]
# > Now we can work on joining the three dataframes. For this project I will be using the **Inner Join** method to combine the dataframes with the help of Pandas bulit in ***Merge*** function.

# %%
# Start by inner joining the 2 larger dataframes 'people_df' and 'vehicle_df'
# The merge function is an inner join by default so we don't need to specify 
p_v_merged = people_df.merge(crashe_df, how='inner', on=['CRASH_RECORD_ID'])
print(p_v_merged.shape)
p_v_merged.head(10).T
# Out:
# (1082930, 30)
#                                                                          0  \
# CRASH_RECORD_ID          81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...
# SEX                                                                      M
# AGE                                                                     25
# SAFETY_EQUIPMENT                                              NONE PRESENT
# DRIVER_ACTION                                                      UNKNOWN
# DRIVER_VISION                                                      UNKNOWN
# PHYSICAL_CONDITION                                                 UNKNOWN
# BAC_RESULT                                                TEST NOT OFFERED
# CRASH_DATE                                          09/28/2019 03:30:00 AM
# POSTED_SPEED_LIMIT                                                      30
# TRAFFIC_CONTROL_DEVICE                                         NO CONTROLS
# DEVICE_CONDITION                                               NO CONTROLS
# WEATHER_CONDITION                                                     RAIN
# LIGHTING_CONDITION                                                DARKNESS
# FIRST_CRASH_TYPE                                      PARKED MOTOR VEHICLE
# TRAFFICWAY_TYPE                                                NOT DIVIDED
# ALIGNMENT                                               STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                   WET
# ROAD_DEFECT                                                     NO DEFECTS
# CRASH_TYPE                                          NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                 NaN
# NOT_RIGHT_OF_WAY_I                                                     NaN
# HIT_AND_RUN_I                                                            Y
# PRIM_CONTRIBUTORY_CAUSE                                UNABLE TO DETERMINE
# SEC_CONTRIBUTORY_CAUSE                                      NOT APPLICABLE
# STREET_DIRECTION                                                         N
# WORK_ZONE_I                                                            NaN
# NUM_UNITS                                                                3
# LATITUDE                                                              41.9
# LONGITUDE                                                         -87.7556
#
#                                                                          1  \
# CRASH_RECORD_ID          af84fb5c8d996fcd3aefd36593c3a02e6e7509eeb27568...
# SEX                                                                      M
# AGE                                                                     37
# SAFETY_EQUIPMENT                                          SAFETY BELT USED
# DRIVER_ACTION                                                         NONE
# DRIVER_VISION                                                 NOT OBSCURED
# PHYSICAL_CONDITION                                                  NORMAL
# BAC_RESULT                                                TEST NOT OFFERED
# CRASH_DATE                                          04/13/2020 10:50:00 PM
# POSTED_SPEED_LIMIT                                                      30
# TRAFFIC_CONTROL_DEVICE                             FLASHING CONTROL SIGNAL
# DEVICE_CONDITION                                      FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                    CLEAR
# LIGHTING_CONDITION                                  DARKNESS, LIGHTED ROAD
# FIRST_CRASH_TYPE                                  SIDESWIPE SAME DIRECTION
# TRAFFICWAY_TYPE                            DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                               STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                   DRY
# ROAD_DEFECT                                                     NO DEFECTS
# CRASH_TYPE                                          NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                 NaN
# NOT_RIGHT_OF_WAY_I                                                     NaN
# HIT_AND_RUN_I                                                            Y
# PRIM_CONTRIBUTORY_CAUSE                        IMPROPER OVERTAKING/PASSING
# SEC_CONTRIBUTORY_CAUSE              FAILING TO REDUCE SPEED TO AVOID CRASH
# STREET_DIRECTION                                                         W
# WORK_ZONE_I                                                            NaN
# NUM_UNITS                                                                2
# LATITUDE                                                            41.736
# LONGITUDE                                                         -87.6534
#
#                                                                          2  \
# CRASH_RECORD_ID          af84fb5c8d996fcd3aefd36593c3a02e6e7509eeb27568...
# SEX                                                                      X
# AGE                                                                    NaN
# SAFETY_EQUIPMENT                                             USAGE UNKNOWN
# DRIVER_ACTION                                             IMPROPER PASSING
# DRIVER_VISION                                                      UNKNOWN
# PHYSICAL_CONDITION                                                 UNKNOWN
# BAC_RESULT                                                TEST NOT OFFERED
# CRASH_DATE                                          04/13/2020 10:50:00 PM
# POSTED_SPEED_LIMIT                                                      30
# TRAFFIC_CONTROL_DEVICE                             FLASHING CONTROL SIGNAL
# DEVICE_CONDITION                                      FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                    CLEAR
# LIGHTING_CONDITION                                  DARKNESS, LIGHTED ROAD
# FIRST_CRASH_TYPE                                  SIDESWIPE SAME DIRECTION
# TRAFFICWAY_TYPE                            DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                               STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                   DRY
# ROAD_DEFECT                                                     NO DEFECTS
# CRASH_TYPE                                          NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                 NaN
# NOT_RIGHT_OF_WAY_I                                                     NaN
# HIT_AND_RUN_I                                                            Y
# PRIM_CONTRIBUTORY_CAUSE                        IMPROPER OVERTAKING/PASSING
# SEC_CONTRIBUTORY_CAUSE              FAILING TO REDUCE SPEED TO AVOID CRASH
# STREET_DIRECTION                                                         W
# WORK_ZONE_I                                                            NaN
# NUM_UNITS                                                                2
# LATITUDE                                                            41.736
# LONGITUDE                                                         -87.6534
#
#                                                                          3  \
# CRASH_RECORD_ID          71162af7bf22799b776547132ebf134b5b438dcf3dac6b...
# SEX                                                                      X
# AGE                                                                    NaN
# SAFETY_EQUIPMENT                                             USAGE UNKNOWN
# DRIVER_ACTION                                             IMPROPER BACKING
# DRIVER_VISION                                                      UNKNOWN
# PHYSICAL_CONDITION                                                 UNKNOWN
# BAC_RESULT                                                TEST NOT OFFERED
# CRASH_DATE                                          11/01/2015 05:00:00 AM
# POSTED_SPEED_LIMIT                                                      30
# TRAFFIC_CONTROL_DEVICE                                         NO CONTROLS
# DEVICE_CONDITION                                               NO CONTROLS
# WEATHER_CONDITION                                                    CLEAR
# LIGHTING_CONDITION                                  DARKNESS, LIGHTED ROAD
# FIRST_CRASH_TYPE                                      PARKED MOTOR VEHICLE
# TRAFFICWAY_TYPE                            DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                               STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                   DRY
# ROAD_DEFECT                                                     NO DEFECTS
# CRASH_TYPE                                          NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                 NaN
# NOT_RIGHT_OF_WAY_I                                                     NaN
# HIT_AND_RUN_I                                                            Y
# PRIM_CONTRIBUTORY_CAUSE                DRIVING SKILLS/KNOWLEDGE/EXPERIENCE
# SEC_CONTRIBUTORY_CAUSE                                      NOT APPLICABLE
# STREET_DIRECTION                                                         W
# WORK_ZONE_I                                                            NaN
# NUM_UNITS                                                                2
# LATITUDE                                                           41.8082
# LONGITUDE                                                         -87.7085
#
#                                                                          4  \
# CRASH_RECORD_ID          c21c476e2ccc41af550b5d858d22aaac4ffc88745a1700...
# SEX                                                                      X
# AGE                                                                    NaN
# SAFETY_EQUIPMENT                                             USAGE UNKNOWN
# DRIVER_ACTION                                                      UNKNOWN
# DRIVER_VISION                                                      UNKNOWN
# PHYSICAL_CONDITION                                                 UNKNOWN
# BAC_RESULT                                                TEST NOT OFFERED
# CRASH_DATE                                          11/01/2015 08:00:00 AM
# POSTED_SPEED_LIMIT                                                      35
# TRAFFIC_CONTROL_DEVICE                                         NO CONTROLS
# DEVICE_CONDITION                                               NO CONTROLS
# WEATHER_CONDITION                                                  UNKNOWN
# LIGHTING_CONDITION                                                 UNKNOWN
# FIRST_CRASH_TYPE                                      PARKED MOTOR VEHICLE
# TRAFFICWAY_TYPE                                                NOT DIVIDED
# ALIGNMENT                                               STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                               UNKNOWN
# ROAD_DEFECT                                                     NO DEFECTS
# CRASH_TYPE                                          NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                 NaN
# NOT_RIGHT_OF_WAY_I                                                     NaN
# HIT_AND_RUN_I                                                            Y
# PRIM_CONTRIBUTORY_CAUSE                                UNABLE TO DETERMINE
# SEC_CONTRIBUTORY_CAUSE                                 UNABLE TO DETERMINE
# STREET_DIRECTION                                                         N
# WORK_ZONE_I                                                            NaN
# NUM_UNITS                                                                2
# LATITUDE                                                           41.9814
# LONGITUDE                                                         -87.6599
#
#                                                                          5  \
# CRASH_RECORD_ID          eb390a4c8e114c69488f5fb8a097fe629f5a92fd528cf4...
# SEX                                                                      X
# AGE                                                                    NaN
# SAFETY_EQUIPMENT                                             USAGE UNKNOWN
# DRIVER_ACTION                                                      UNKNOWN
# DRIVER_VISION                                                      UNKNOWN
# PHYSICAL_CONDITION                                                 UNKNOWN
# BAC_RESULT                                                TEST NOT OFFERED
# CRASH_DATE                                          11/01/2015 10:15:00 AM
# POSTED_SPEED_LIMIT                                                      10
# TRAFFIC_CONTROL_DEVICE                                         NO CONTROLS
# DEVICE_CONDITION                                               NO CONTROLS
# WEATHER_CONDITION                                                    CLEAR
# LIGHTING_CONDITION                                                DAYLIGHT
# FIRST_CRASH_TYPE                                      PARKED MOTOR VEHICLE
# TRAFFICWAY_TYPE                                                PARKING LOT
# ALIGNMENT                                               STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                   DRY
# ROAD_DEFECT                                                     NO DEFECTS
# CRASH_TYPE                                          NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                 NaN
# NOT_RIGHT_OF_WAY_I                                                       Y
# HIT_AND_RUN_I                                                            Y
# PRIM_CONTRIBUTORY_CAUSE                                UNABLE TO DETERMINE
# SEC_CONTRIBUTORY_CAUSE                                      NOT APPLICABLE
# STREET_DIRECTION                                                         S
# WORK_ZONE_I                                                            NaN
# NUM_UNITS                                                                2
# LATITUDE                                                           41.8095
# LONGITUDE                                                         -87.6064
#
#                                                                          6  \
# CRASH_RECORD_ID          dd1bce4bd6d0be4c247714dcabab44e6563c62b913229b...
# SEX                                                                      X
# AGE                                                                    NaN
# SAFETY_EQUIPMENT                                             USAGE UNKNOWN
# DRIVER_ACTION                                                      UNKNOWN
# DRIVER_VISION                                                      UNKNOWN
# PHYSICAL_CONDITION                                                 UNKNOWN
# BAC_RESULT                                                TEST NOT OFFERED
# CRASH_DATE                                          11/01/2015 11:00:00 AM
# POSTED_SPEED_LIMIT                                                      25
# TRAFFIC_CONTROL_DEVICE                                         NO CONTROLS
# DEVICE_CONDITION                                               NO CONTROLS
# WEATHER_CONDITION                                                    CLEAR
# LIGHTING_CONDITION                                                 UNKNOWN
# FIRST_CRASH_TYPE                                      PARKED MOTOR VEHICLE
# TRAFFICWAY_TYPE                                                    ONE-WAY
# ALIGNMENT                                               STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                   DRY
# ROAD_DEFECT                                                     NO DEFECTS
# CRASH_TYPE                                          NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                 NaN
# NOT_RIGHT_OF_WAY_I                                                     NaN
# HIT_AND_RUN_I                                                            Y
# PRIM_CONTRIBUTORY_CAUSE                                UNABLE TO DETERMINE
# SEC_CONTRIBUTORY_CAUSE                                 UNABLE TO DETERMINE
# STREET_DIRECTION                                                         S
# WORK_ZONE_I                                                            NaN
# NUM_UNITS                                                                2
# LATITUDE                                                           41.7332
# LONGITUDE                                                         -87.6546
#
#                                                                          7  \
# CRASH_RECORD_ID          4bd2ee6bb306902b99a9c2ae55cf4fcffec00879e39759...
# SEX                                                                      X
# AGE                                                                    NaN
# SAFETY_EQUIPMENT                                             USAGE UNKNOWN
# DRIVER_ACTION                                                      UNKNOWN
# DRIVER_VISION                                                      UNKNOWN
# PHYSICAL_CONDITION                                                 UNKNOWN
# BAC_RESULT                                                TEST NOT OFFERED
# CRASH_DATE                                          11/01/2015 12:30:00 PM
# POSTED_SPEED_LIMIT                                                      30
# TRAFFIC_CONTROL_DEVICE                                         NO CONTROLS
# DEVICE_CONDITION                                               NO CONTROLS
# WEATHER_CONDITION                                                    CLEAR
# LIGHTING_CONDITION                                                DAYLIGHT
# FIRST_CRASH_TYPE                                      PARKED MOTOR VEHICLE
# TRAFFICWAY_TYPE                                                    ONE-WAY
# ALIGNMENT                                               STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                   DRY
# ROAD_DEFECT                                                     NO DEFECTS
# CRASH_TYPE                                          NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                 NaN
# NOT_RIGHT_OF_WAY_I                                                     NaN
# HIT_AND_RUN_I                                                          NaN
# PRIM_CONTRIBUTORY_CAUSE                                UNABLE TO DETERMINE
# SEC_CONTRIBUTORY_CAUSE                                 UNABLE TO DETERMINE
# STREET_DIRECTION                                                         S
# WORK_ZONE_I                                                            NaN
# NUM_UNITS                                                                2
# LATITUDE                                                           41.8696
# LONGITUDE                                                         -87.7303
#
#                                                                          8  \
# CRASH_RECORD_ID          9c03b6fcc6d72cf3ee2cb9ea754ea7e4617ab965142552...
# SEX                                                                      X
# AGE                                                                    NaN
# SAFETY_EQUIPMENT                                             USAGE UNKNOWN
# DRIVER_ACTION                                                      UNKNOWN
# DRIVER_VISION                                                      UNKNOWN
# PHYSICAL_CONDITION                                                 UNKNOWN
# BAC_RESULT                                                TEST NOT OFFERED
# CRASH_DATE                                          10/31/2015 04:00:00 PM
# POSTED_SPEED_LIMIT                                                      15
# TRAFFIC_CONTROL_DEVICE                                         NO CONTROLS
# DEVICE_CONDITION                                               NO CONTROLS
# WEATHER_CONDITION                                                     RAIN
# LIGHTING_CONDITION                                                    DAWN
# FIRST_CRASH_TYPE                                      PARKED MOTOR VEHICLE
# TRAFFICWAY_TYPE                                                PARKING LOT
# ALIGNMENT                                               STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                   WET
# ROAD_DEFECT                                                     NO DEFECTS
# CRASH_TYPE                                          NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                 NaN
# NOT_RIGHT_OF_WAY_I                                                       Y
# HIT_AND_RUN_I                                                            Y
# PRIM_CONTRIBUTORY_CAUSE                                UNABLE TO DETERMINE
# SEC_CONTRIBUTORY_CAUSE                                      NOT APPLICABLE
# STREET_DIRECTION                                                         W
# WORK_ZONE_I                                                            NaN
# NUM_UNITS                                                                2
# LATITUDE                                                           41.9098
# LONGITUDE                                                         -87.7434
#
#                                                                          9
# CRASH_RECORD_ID          2e7e0c1682100a200a46c25a532eda4febb00a2ae49ea9...
# SEX                                                                      X
# AGE                                                                    NaN
# SAFETY_EQUIPMENT                                             USAGE UNKNOWN
# DRIVER_ACTION                                                      UNKNOWN
# DRIVER_VISION                                                      UNKNOWN
# PHYSICAL_CONDITION                                                 UNKNOWN
# BAC_RESULT                                                TEST NOT OFFERED
# CRASH_DATE                                          09/02/2015 02:35:00 PM
# POSTED_SPEED_LIMIT                                                      30
# TRAFFIC_CONTROL_DEVICE                                         NO CONTROLS
# DEVICE_CONDITION                                               NO CONTROLS
# WEATHER_CONDITION                                                    CLEAR
# LIGHTING_CONDITION                                                DAYLIGHT
# FIRST_CRASH_TYPE                                      PARKED MOTOR VEHICLE
# TRAFFICWAY_TYPE                                                NOT DIVIDED
# ALIGNMENT                                               STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                   DRY
# ROAD_DEFECT                                                     NO DEFECTS
# CRASH_TYPE                                          NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                 NaN
# NOT_RIGHT_OF_WAY_I                                                     NaN
# HIT_AND_RUN_I                                                          NaN
# PRIM_CONTRIBUTORY_CAUSE                                UNABLE TO DETERMINE
# SEC_CONTRIBUTORY_CAUSE                                 UNABLE TO DETERMINE
# STREET_DIRECTION                                                         N
# WORK_ZONE_I                                                              Y
# NUM_UNITS                                                                2
# LATITUDE                                                           41.8962
# LONGITUDE                                                         -87.6402

# %% [markdown]
# > As we can see the merge was succeful
